# %%
import pandas as pd
import numpy as np
import json 
import ast

# %%
movies_data = pd.read_csv("movies_dataset.csv")
movies_data.head()
# Out:
# C:\Users\ROG BY NG\AppData\Local\Temp\ipykernel_5876\1660679691.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   movies_data = pd.read_csv("movies_dataset.csv")
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
# ...

# %% [markdown]
# *Visualizacion Nombre de Columnas*

# %%
movies_data.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %% [markdown]
# *Descripcion del Dataset*

# %% [markdown]
# ##	Descripción De Columnas
#
# **adult:**	Indica si la película tiene califiación X, exclusiva para adultos.
#
# **belongs_to_collection:** Un diccionario que indica a que franquicia o serie de películas pertenece la película.
#
# **budget:**	El presupuesto de la película, en dólares.
#
# **genres:**	Un diccionario que indica todos los géneros asociados a la película.
#
# **homepage:**	La página web oficial de la película.
#
# **id:**	ID de la pelicula.
#
# **imdb_id:**	IMDB ID de la pelicula.
#
# **original_language:**	Idioma original en la que se grabo la pelicula.
#
# **original_title:**	Titulo original de la pelicula.
#
# **overview:**	Pequeño resumen de la película.
#
# **popularity:**	Puntaje de popularidad de la película, asignado por TMDB (TheMoviesDataBase).
#
# **poster_path:**	URL del póster de la película.
#
# **production_companies:**	Lista con las compañias productoras asociadas a la película.
#
# **production_countries:**	Lista con los países donde se produjo la película.
#
# **release_date:**	Fecha de estreno de la película.
#
# **revenue:**	Recaudación de la pelicula, en dolares.
#
# **runtime:**	Duración de la película, en minutos.
#
# **spoken_languages:**	Lista con los idiomas que se hablan en la pelicula.
#
# **status:** 	Estado de la pelicula actual (si fue anunciada, si ya se estreno, etc).
#
# **tagline:** Frase celebre asociadaa la pelicula.
#
# **title:** Titulo de la pelicula.
#
# **video:** Indica si hay o no un trailer en video disponible en TMDB.
#
# **vote_average:** Puntaje promedio de reseñas de la pelicula.
#
# **vote_count:**	 Numeros de votos recibidos por la pelicula, en TMDB.

# %%
movies_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %% [markdown]
# Elimar filas vacias

# %%
movies_data.drop([35587,19730,29503], axis=0, inplace=True)

# %% [markdown]
# Cambiar tipo de obj a int

# %%
movies_data['id'] = movies_data['id'].astype(int)

# %% [markdown]
# Visulaizar duplicados

# %%
print( movies_data.id.duplicated().sum())
# Out:
# 30

# %% [markdown]
# Eliminar duplicados

# %%
movies_data.drop_duplicates(subset='id',keep="first" ,inplace=True)

# %% [markdown]
# 1.  Eliminar las columnas que no serán utilizadas, video, imdb_id, adult, original_title, poster_path y homepage.

# %%
movies_data.drop(["video", "imdb_id","adult", "original_title", "poster_path", "homepage"], axis = 1, inplace = True)

# %% [markdown]
# 2. Los valores nulos de los campos revenue, budget deben ser rellenados por el número 0.

# %%
movies_data.budget.fillna(0,inplace=True)
movies_data.revenue.fillna(0, inplace=True)

# %% [markdown]
# 3.  Los valores nulos del campo release date deben eliminarse.

# %%
movies_data.dropna(subset=["release_date"], inplace=True)
movies_data.reset_index(drop=True, inplace=True) # Restablece el índice en un orden secuencial y modifica el DataFrame original

# %% [markdown]
# 4. De haber fechas, deberán tener el formato AAAA-mm-dd, además deberán crear la columna release_year donde extraerán el año de la fecha de estreno.

# %%
movies_data.release_date=pd.to_datetime(movies_data['release_date'], format='%Y-%m-%d', errors='coerce')# Convertir columna en formato datetime

movies_data["release_year"]=movies_data.release_date.dt.year#Extarer año de la columna release_date

movies_data.reset_index(drop=True,inplace=True) # reiniciar index

movies_data.dropna(subset=['release_date'], inplace=True) # eliminar filas con errores

movies_data['release_year'] = movies_data['release_year'].astype(int, errors = 'raise')##Cambiar tipo de dato a int

# %% [markdown]
# Visualizar cambios en el dataframe

# %%
movies_data.head()
# Out:
#                                belongs_to_collection    budget  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                NaN  65000000
# 2  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                NaN  16000000
# 4  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres     id original_language  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...    862                en
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...   8844                en
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...  15602                en
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  31357                en
# 4                     [{'id': 35, 'name': 'Comedy'}]  11862                en
#
#                                             overview popularity  \
# ...

# %% [markdown]
# 5.  Crear la columna con el retorno de inversión, llamada return con los campos revenue y budget, dividiendo estas dos últimas revenue / budget, cuando no hay datos disponibles para calcularlo, deberá tomar el valor 0.

# %%
movies_data['budget'] = movies_data['budget'].astype(float) # Convertir,formato de columna tipo float

# %%
movies_data['return'] = movies_data['revenue'] / movies_data['budget'] #Crear columna return con el calculo retorno de la inversion
movies_data['return'].fillna(0, inplace=True)# Reemplaza los valores NaN (no disponibles) con 0

# %% [markdown]
# 6. Algunos campos, como belongs_to_collection, production_companies y otros (ver diccionario de datos) están anidados, esto es o bien tienen un diccionario o una lista como valores en cada fila, ¡deberán desanidarlos para poder y unirlos al dataset de nuevo hacer alguna de las consultas de la API! O bien buscar la manera de acceder a esos datos sin desanidarlos.

# %%
def convert_diccionario(diccionario):## Function to eval row datatype=dictionary and then extract it
    if isinstance(diccionario,str) and "{" in diccionario:
        dic=ast.literal_eval(diccionario)
        return dic["name"]

# %%
movies_data["belongs_to_collection"]=movies_data["belongs_to_collection"].apply(convert_diccionario)## Apply dictionary function

# %%
movies_data["belongs_to_collection"]
# Out:
# 0                  Toy Story Collection
# 1                                  None
# 2             Grumpy Old Men Collection
# 3                                  None
# 4        Father of the Bride Collection
#                       ...
# 45341                              None
# 45342                              None
# 45343                              None
# 45344                              None
# 45345                              None
# Name: belongs_to_collection, Length: 45346, dtype: object

# %%
#Production_companies => List

# %%
def convert_lista(lista):## Función para evaluar la fila tipo de datos = lista y luego extraerla
    if isinstance(lista, str) and "{" in lista:
        L=[]
        for i in ast.literal_eval(lista):
            L.append(i["name"])
        return L

# %%
movies_data["production_companies"]=movies_data["production_companies"].apply(convert_lista)## Apply list function
movies_data["genres"]=movies_data["genres"].apply(convert_lista)
movies_data["production_countries"]=movies_data["production_countries"].apply(convert_lista)

# %%
movies_data["spoken_languages"]=movies_data["spoken_languages"].apply(convert_lista)

# %%
movies_data.head()
# Out:
#             belongs_to_collection      budget                        genres  \
# 0            Toy Story Collection  30000000.0   [Animation, Comedy, Family]
# 1                            None  65000000.0  [Adventure, Fantasy, Family]
# 2       Grumpy Old Men Collection         0.0             [Romance, Comedy]
# 3                            None  16000000.0      [Comedy, Drama, Romance]
# 4  Father of the Bride Collection         0.0                      [Comedy]
#
#       id original_language                                           overview  \
# 0    862                en  Led by Woody, Andy's toys live happily in his ...
# 1   8844                en  When siblings Judy and Peter discover an encha...
# 2  15602                en  A family wedding reignites the ancient feud be...
# 3  31357                en  Cheated on, mistreated and stepped on, the wom...
# 4  11862                en  Just when George Banks has recovered from his ...
#
# ...

# %%
movies_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45346 entries, 0 to 45345
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4485 non-null   object
#  1   budget                 45346 non-null  float64
#  2   genres                 42962 non-null  object
#  3   id                     45346 non-null  int32
#  4   original_language      45335 non-null  object
#  5   overview               44405 non-null  object
#  6   popularity             45346 non-null  object
#  7   production_companies   33557 non-null  object
#  8   production_countries   39138 non-null  object
#  9   release_date           45346 non-null  datetime64[ns]
#  10  revenue                45346 non-null  float64
#  11  runtime                45100 non-null  float64
#  12  spoken_languages       41580 non-null  object
#  13  status                 45266 non-null  object
# ...

# %%
movies_data.to_csv("MOVIES_ETL.csv")

# %% [markdown]
# Prueba: importar y visualizar

# %%
Prueba = pd.read_csv("MOVIES_ETL.csv", )
Prueba
# Out:
#        Unnamed: 0           belongs_to_collection      budget  \
# 0               0            Toy Story Collection  30000000.0
# 1               1                             NaN  65000000.0
# 2               2       Grumpy Old Men Collection         0.0
# 3               3                             NaN  16000000.0
# 4               4  Father of the Bride Collection         0.0
# ...           ...                             ...         ...
# 45341       45341                             NaN         0.0
# 45342       45342                             NaN         0.0
# 45343       45343                             NaN         0.0
# 45344       45344                             NaN         0.0
# 45345       45345                             NaN         0.0
#
#                                    genres      id original_language  \
# 0       ['Animation', 'Comedy', 'Family']     862                en
# 1      ['Adventure', 'Fantasy', 'Family']    8844                en
# ...
